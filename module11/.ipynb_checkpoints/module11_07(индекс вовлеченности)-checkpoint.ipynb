# %% [markdown]
# # Лайки, комментарии и репосты
# Для создания полноценного отчета по лучшим публикациям нам необходимо выделять посты, которые были опубликованы в определенный период. На данном этапе будем использовать самый простой вариант - берем последние 100 постов группы и фильтруем те, что были опубликованы вчера. Мы продолжаем работать с группой https://vk.com/habr
#
# Начнем с импорта токена и формирования запроса к API ВКонтакте методом wall.get (https://vk.com/dev/wall.get):

# %%
import requests
from yaml import load
from pprint import pprint
import pandas as pd
pd.set_option("display.max_rows", 20)

# %%
with open('./module11_files/config.yaml', 'r') as f:
    config = load(f)

token = config['access_token']

# %%
def get_100articles(group_id, n_art=100):
    
    url = 'https://api.vk.com/method/wall.get'

    params = {
        'domain': group_id,
        'filter': 'owner',
        'count': n_art,
        'offset': 0,
        'access_token': token,
        'v': 5.73
    }

    return requests.get(url, params = params).json()

# %%
data = get_100articles('habr')
pprint(data)
# Out:
# {'response': {'count': 96506,
#               'items': [{'attachments': [{'photo': {'access_key': '9e1a8b5cb8bc3b801d',
#                                                     'album_id': -7,
#                                                     'date': 1544169649,
#                                                     'height': 420,
#                                                     'id': 456256288,
#                                                     'owner_id': -20629724,
#                                                     'photo_130': 'https://sun9-33.userapi.com/c635101/v635101837/4458f/pvOM7kijXLo.jpg',
#                                                     'photo_604': 'https://sun9-29.userapi.com/c635101/v635101837/44590/awP4AyVy320.jpg',
#                                                     'photo_75': 'https://sun9-33.userapi.com/c635101/v635101837/4458e/HBWPoRODBB0.jpg',
#                                                     'photo_807': 'https://sun9-34.userapi.com/c635101/v635101837/44591/28A4SqqRYfQ.jpg',
#                                                     'post_id': 1136473,
#                                                     'text': '«Не надо сразу '
#                                                             'бросаться строить '
#                                                             'подводную '
#                                                             'лодку».\n'
#                                                             '\n'
#                                                             'Беседуем с '
#                                                             'руководителем '
#                                                             'мобильной '
#                                                             'разработки '
#                                                             '«Лаборатории '
#                                                             'Касперского» '
#                                                             'Виктором '
#                                                             'Яблоковым о том, '
#                                                             'чем ему помог в '
#                                                             'IT математический '
#                                                             'аппарат, как '
#                                                             'мобильная '
#                                                             'разработка '
#                                                             'встраивается в '
#                                                             'структуру '
#                                                             'компании, с '
#                                                             'какими угрозами '
#                                                             'имеет дело его '
#                                                             'команда, какие у '
#                                                             '«Лаборатории '
#                                                             'Касперского» '
#                                                             'патенты и о массе '
#                                                             'других '
#                                                             'технических и '
#                                                             'мировоззренческих '
#                                                             'вещей: '
#                                                             'http://amp.gs/go83\n'
#                                                             '\n'
#                                                             '#разработка@habr '
#                                                             '#управление@habr',
#                                                     'user_id': 100,
#                                                     'width': 800},
#                                           'type': 'photo'}],
#                          'comments': {'can_post': 1,
#                                       'count': 1,
#                                       'groups_can_post': True},
#                          'date': 1544169649,
#                          'from_id': -20629724,
#                          'id': 1136473,
#                          'is_pinned': 1,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 59,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -20629724,
#                          'post_source': {'type': 'api'},
#                          'post_type': 'post',
#                          'reposts': {'count': 9, 'user_reposted': 0},
#                          'text': '«Не надо сразу бросаться строить подводную '
#                                  'лодку».\n'
#                                  '\n'
#                                  'Беседуем с руководителем мобильной '
#                                  'разработки «Лаборатории Касперского» '
#                                  'Виктором Яблоковым о том, чем ему помог в IT '
#                                  'математический аппарат, как мобильная '
#                                  'разработка встраивается в структуру '
#                                  'компании, с какими угрозами имеет дело его '
#                                  'команда, какие у «Лаборатории Касперского» '
#                                  'патенты и о массе других технических и '
#                                  'мировоззренческих вещей: http://amp.gs/go83\n'
#                                  '\n'
#                                  '#разработка@habr #управление@habr',
#                          'views': {'count': 28763}},
#                         {'attachments': [{'photo': {'access_key': 'efa67a382735068441',
#                                                     'album_id': -7,
#                                                     'date': 1544367635,
#                                                     'height': 750,
#                                                     'id': 456256390,
#                                                     'owner_id': -20629724,
#                                                     'photo_1280': 'https://sun9-35.userapi.com/c635101/v635101136/2d0b6/YiZOP0r0ecs.jpg',
#                                                     'photo_130': 'https://sun9-28.userapi.com/c635101/v635101136/2d0b3/WcfqIktm4qg.jpg',
#                                                     'photo_604': 'https://sun9-4.userapi.com/c635101/v635101136/2d0b4/5J4-qWvHYrk.jpg',
#                                                     'photo_75': 'https://sun9-3.userapi.com/c635101/v635101136/2d0b2/g192yYwcmxU.jpg',
#                                                     'photo_807': 'https://sun9-28.userapi.com/c635101/v635101136/2d0b5/PqbwLJQq9a8.jpg',
#                                                     'post_id': 1137333,
#                                                     'text': 'Несколько дней '
#                                                             'назад стартап '
#                                                             'Waymo, '
#                                                             'принадлежащий '
#                                                             'Alphabet, '
#                                                             'запустил в '
#                                                             'коммерческую '
#                                                             'эксплуатацию '
#                                                             'беспилотное '
#                                                             'такси.\n'
#                                                             '\n'
#                                                             'Согласно оценкам '
#                                                             'аналитиков '
#                                                             'инвестиционного '
#                                                             'банка UBS, '
#                                                             'развитие этого '
#                                                             'направления '
#                                                             'бизнеса к 2030 '
#                                                             'году будет '
#                                                             'генерировать $114 '
#                                                             'млрд выручки: '
#                                                             'http://amp.gs/gcOr\n'
#                                                             '\n'
#                                                             '#гиктаймс@habr',
#                                                     'user_id': 100,
#                                                     'width': 1200},
#                                           'type': 'photo'}],
#                          'comments': {'can_post': 1,
#                                       'count': 1,
#                                       'groups_can_post': True},
#                          'date': 1544367635,
#                          'from_id': -20629724,
#                          'id': 1137333,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 32,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -20629724,
#                          'post_source': {'type': 'api'},
#                          'post_type': 'post',
#                          'reposts': {'count': 3, 'user_reposted': 0},
#                          'text': 'Несколько дней назад стартап Waymo, '
#                                  'принадлежащий Alphabet, запустил в '
#                                  'коммерческую эксплуатацию беспилотное '
#                                  'такси.\n'
#                                  '\n'
#                                  'Согласно оценкам аналитиков инвестиционного '
#                                  'банка UBS, развитие этого направления '
#                                  'бизнеса к 2030 году будет генерировать $114 '
#                                  'млрд выручки: http://amp.gs/gcOr\n'
#                                  '\n'
#                                  '#гиктаймс@habr',
#                          'views': {'count': 19222}},
#                         {'attachments': [{'photo': {'access_key': 'ca163e98b0ef66706e',
#                                                     'album_id': -7,
#                                                     'date': 1544360422,
#                                                     'height': 498,
#                                                     'id': 456256386,
#                                                     'owner_id': -20629724,
#                                                     'photo_1280': 'https://sun9-24.userapi.com/c635101/v635101929/3ac62/aHHEV7y-M_A.jpg',
#                                                     'photo_130': 'https://sun9-1.userapi.com/c635101/v635101929/3ac5f/-v0Xd-7sFzg.jpg',
#                                                     'photo_604': 'https://sun9-3.userapi.com/c635101/v635101929/3ac60/zbM002cIwPs.jpg',
#                                                     'photo_75': 'https://sun9-4.userapi.com/c635101/v635101929/3ac5e/S8gx-lPEA-Y.jpg',
#                                                     'photo_807': 'https://sun9-24.userapi.com/c635101/v635101929/3ac61/YbDJlRPttOw.jpg',
#                                                     'post_id': 1137314,
#                                                     'text': '«Пассивная '
#                                                             'разведка — '
#                                                             'основной '
#                                                             'инструмент, '
#                                                             'который вы '
#                                                             'действительно '
#                                                             'должны '
#                                                             'попробовать».\n'
#                                                             '\n'
#                                                             'Конференция '
#                                                             'DEFCON 18. «Вы '
#                                                             'потратили все эти '
#                                                             'деньги, но вас '
#                                                             'продолжают '
#                                                             'иметь». Часть '
#                                                             'первая: '
#                                                             'http://amp.gs/gcyq\n'
#                                                             '\n'
#                                                             '#разработка@habr '
#                                                             '#администрирование@habr '
#                                                             '#маркетинг@habr',
#                                                     'user_id': 100,
#                                                     'width': 1000},
#                                           'type': 'photo'}],
#                          'comments': {'can_post': 1,
#                                       'count': 0,
#                                       'groups_can_post': True},
#                          'date': 1544360422,
#                          'from_id': -20629724,
#                          'id': 1137314,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 42,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -20629724,
#                          'post_source': {'type': 'api'},
#                          'post_type': 'post',
#                          'reposts': {'count': 9, 'user_reposted': 0},
#                          'text': '«Пассивная разведка — основной инструмент, '
#                                  'который вы действительно должны '
#                                  'попробовать».\n'
#                                  '\n'
#                                  'Конференция DEFCON 18. «Вы потратили все эти '
#                                  'деньги, но вас продолжают иметь». Часть '
#                                  'первая: http://amp.gs/gcyq\n'
#                                  '\n'
#                                  '#разработка@habr #администрирование@habr '
#                                  '#маркетинг@habr',
#                          'views': {'count': 24688}},
#                         {'comments': {'can_post': 1,
#                                       'count': 3,
#                                       'groups_can_post': True},
#                          'copy_history': [{'attachments': [{'link': {'caption': 'moikrug.ru',
#                                                                      'description': 'Компания '
#                                                                                     '«Finangel». '
#                                                                                     'Революционный '
#                                                                                     'стартап '
#                                                                                     'в '
#                                                                                     'области '
#                                                                                     'необанкинга. '
#                                                                                     'Санкт-Петербург. '
#                                                                                     'От '
#                                                                                     '170 '
#                                                                                     '000 '
#                                                                                     'до '
#                                                                                     '200 '
#                                                                                     '000 '
#                                                                                     'руб. '
#                                                                                     'Полный '
#                                                                                     'рабочий '
#                                                                                     'день.',
#                                                                      'photo': {'album_id': -27,
#                                                                                'date': 1543327340,
#                                                                                'height': 150,
#                                                                                'id': 456261599,
#                                                                                'owner_id': 2000025313,
#                                                                                'photo_130': 'https://pp.userapi.com/c849120/v849120791/baa22/BPkrLf-JlcQ.jpg',
#                                                                                'photo_604': 'https://pp.userapi.com/c849120/v849120791/baa23/3wQpB08dc9E.jpg',
#                                                                                'photo_75': 'https://pp.userapi.com/c849120/v849120791/baa21/7dpPJ-HDnkA.jpg',
#                                                                                'text': '',
#                                                                                'width': 150},
#                                                                      'title': 'Требуется '
#                                                                               '«React '
#                                                                               'Native '
#                                                                               'developer»',
#                                                                      'url': 'https://moikrug.ru/vacancies/1000047149?f=social'},
#                                                             'type': 'link'}],
#                                            'date': 1543327331,
#                                            'from_id': -46638176,
#                                            'id': 41077,
#                                            'owner_id': -46638176,
#                                            'post_source': {'type': 'api'},
#                                            'post_type': 'post',
#                                            'text': 'Требуется «React Native '
#                                                    'developer» '
#                                                    '(Санкт-Петербург, от 170 '
#                                                    '000 до 200 000 руб.)\n'
#                                                    '\n'
#                                                    'Компания «Finangel». '
#                                                    'Революционный стартап в '
#                                                    'области необанкинга. '
#                                                    'Россия, Санкт-Петербург. '
#                                                    'От 170 000 руб. до 200 000 '
#                                                    'руб. Полный рабочий '
#                                                    'день. \n'
#                                                    '\n'
#                                                    'Требуемые навыки: '
#                                                    '#frontend@moikrug, '
#                                                    '#ReactNative, #Redux, '
#                                                    '#Typescript, #React.js. \n'
#                                                    '\n'
#                                                    'Откликнуться на вакансию: '
#                                                    'https://moikrug.ru/vacancies/1000047149?f=social'}],
#                          'date': 1544359800,
#                          'from_id': -20629724,
#                          'id': 1137313,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 6,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -20629724,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 0, 'user_reposted': 0},
#                          'text': '',
#                          'views': {'count': 21443}},
#                         {'attachments': [{'photo': {'access_key': '7e8214334f94f523df',
#                                                     'album_id': -7,
#                                                     'date': 1544356897,
#                                                     'height': 638,
#                                                     'id': 456256384,
#                                                     'owner_id': -20629724,
#                                                     'photo_1280': 'https://sun9-36.userapi.com/c635101/v635101361/3456e/2PEqu7-vHYc.jpg',
#                                                     'photo_130': 'https://sun9-27.userapi.com/c635101/v635101361/3456b/WAN5xirT8xg.jpg',
#                                                     'photo_604': 'https://sun9-4.userapi.com/c635101/v635101361/3456c/aqSDP2sXUsQ.jpg',
#                                                     'photo_75': 'https://sun9-23.userapi.com/c635101/v635101361/3456a/LvtMeA6_BUU.jpg',
#                                                     'photo_807': 'https://sun9-30.userapi.com/c635101/v635101361/3456d/8LoxnydLHL8.jpg',
#                                                     'post_id': 1137302,
#                                                     'text': 'На прошедшей '
#                                                             'неделе мы '
#                                                             'разочаровывались '
#                                                             'в '
#                                                             'диджитал-услугах, '
#                                                             'тестировали новый '
#                                                             '2ГИС, знакомились '
#                                                             'с '
#                                                             '«Яндекс.Телефоном», '
#                                                             'ваяли 2D-квест по '
#                                                             'Лавкрафту и '
#                                                             'радовались '
#                                                             'переходу на '
#                                                             'опенсорс самого '
#                                                             'популярного в '
#                                                             'мире движка '
#                                                             'физической '
#                                                             'симуляции.\n'
#                                                             '\n'
#                                                             'Десять лучших '
#                                                             'публикаций недели '
#                                                             '(3-9 декабря):\n'
#                                                             '\n'
#                                                             '— Встречаем '
#                                                             '«Яндекс.Телефон» '
#                                                             '— теперь '
#                                                             'официально: '
#                                                             'http://amp.gs/gcC5\n'
#                                                             '— «Ты крутой '
#                                                             'разраб, иди и '
#                                                             'попроси больше '
#                                                             'денег», или '
#                                                             'Рассказываем '
#                                                             'менеджерам, как '
#                                                             'устроен мир: '
#                                                             'http://amp.gs/gcCb\n'
#                                                             '— Fuck Up story, '
#                                                             'или Как '
#                                                             'разочароваться в '
#                                                             'digital-услугах '
#                                                             'для бизнеса и '
#                                                             'проиметь своё '
#                                                             'дело: '
#                                                             'http://amp.gs/gckI\n'
#                                                             '— Публичное '
#                                                             'тестирование '
#                                                             'нового 2ГИС: '
#                                                             'http://amp.gs/gcC6\n'
#                                                             '— Nvidia сошла с '
#                                                             'ума и открывает '
#                                                             'PhysX под BSD-3: '
#                                                             'http://amp.gs/gckj\n'
#                                                             '— Любопытные '
#                                                             'извращения из '
#                                                             'мира ИТ: '
#                                                             'http://amp.gs/gckT\n'
#                                                             '— Разнообразие '
#                                                             'браузеров '
#                                                             'начинается с нас, '
#                                                             'поэтому '
#                                                             'тестируйте все '
#                                                             'ваши сайты в '
#                                                             'Firefox: '
#                                                             'http://amp.gs/gck1\n'
#                                                             '— Европа '
#                                                             'собирается '
#                                                             'построить '
#                                                             'гравитационно-волновой '
#                                                             'детектор нового '
#                                                             'поколения под '
#                                                             'названием '
#                                                             'Einstein '
#                                                             'Telescope: '
#                                                             'http://amp.gs/gckY\n'
#                                                             '— История о '
#                                                             'тернистом пути '
#                                                             'разработки '
#                                                             '2D-квеста в '
#                                                             'сеттинге миров '
#                                                             'Говарда '
#                                                             'Лавкрафта: '
#                                                             'http://amp.gs/gckm\n'
#                                                             '— Полицейские '
#                                                             'Калифорнии в '
#                                                             'течение семи '
#                                                             'минут пытались '
#                                                             'остановить Tesla '
#                                                             'с заснувшим за '
#                                                             'рулем водителем: '
#                                                             'http://amp.gs/gckZ\n'
#                                                             '\n'
#                                                             '#weeklydigest@habr',
#                                                     'user_id': 100,
#                                                     'width': 1134},
#                                           'type': 'photo'}],
#                          'comments': {'can_post': 1,
#                                       'count': 15,
#                                       'groups_can_post': True},
#                          'date': 1544356897,
#                          'from_id': -20629724,
#                          'id': 1137302,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 52,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -20629724,
#                          'post_source': {'type': 'api'},
#                          'post_type': 'post',
#                          'reposts': {'count': 5, 'user_reposted': 0},
#                          'text': 'На прошедшей неделе мы разочаровывались в '
#                                  'диджитал-услугах, тестировали новый 2ГИС, '
#                                  'знакомились с «Яндекс.Телефоном», ваяли '
#                                  '2D-квест по Лавкрафту и радовались переходу '
#                                  'на опенсорс самого популярного в мире движка '
#                                  'физической симуляции.\n'
#                                  '\n'
#                                  'Десять лучших публикаций недели (3-9 '
#                                  'декабря):\n'
#                                  '\n'
#                                  '— Встречаем «Яндекс.Телефон» — теперь '
#                                  'официально: http://amp.gs/gcC5\n'
#                                  '— «Ты крутой разраб, иди и попроси больше '
#                                  'денег», или Рассказываем менеджерам, как '
#                                  'устроен мир: http://amp.gs/gcCb\n'
#                                  '— Fuck Up story, или Как разочароваться в '
#                                  'digital-услугах для бизнеса и проиметь своё '
#                                  'дело: http://amp.gs/gckI\n'
#                                  '— Публичное тестирование нового 2ГИС: '
#                                  'http://amp.gs/gcC6\n'
#                                  '— Nvidia сошла с ума и открывает PhysX под '
#                                  'BSD-3: http://amp.gs/gckj\n'
#                                  '— Любопытные извращения из мира ИТ: '
#                                  'http://amp.gs/gckT\n'
#                                  '— Разнообразие браузеров начинается с нас, '
#                                  'поэтому тестируйте все ваши сайты в Firefox: '
#                                  'http://amp.gs/gck1\n'
#                                  '— Европа собирается построить '
#                                  'гравитационно-волновой детектор нового '
#                                  'поколения под названием Einstein Telescope: '
#                                  'http://amp.gs/gckY\n'
#                                  '— История о тернистом пути разработки '
#                                  '2D-квеста в сеттинге миров Говарда '
#                                  'Лавкрафта: http://amp.gs/gckm\n'
#                                  '— Полицейские Калифорнии в течение семи '
#                                  'минут пытались остановить Tesla с заснувшим '
#                                  'за рулем водителем: http://amp.gs/gckZ\n'
#                                  '\n'
#                                  '#weeklydigest@habr',
#                          'views': {'count': 27029}},
#                         {'attachments': [{'photo': {'access_key': '9293a9162022ddb5bd',
#                                                     'album_id': -7,
#                                                     'date': 1544353234,
#                                                     'height': 581,
#                                                     'id': 456256383,
#                                                     'owner_id': -20629724,
#                                                     'photo_1280': 'https://sun9-26.userapi.com/c635101/v635101798/3b831/rEeOnvAdfKA.jpg',
#                                                     'photo_130': 'https://sun9-1.userapi.com/c635101/v635101798/3b82e/nJ-ZU5evjc4.jpg',
#                                                     'photo_604': 'https://sun9-4.userapi.com/c635101/v635101798/3b82f/atws6jgRs9M.jpg',
#                                                     'photo_75': 'https://sun9-36.userapi.com/c635101/v635101798/3b82d/5O8z0mmyGDU.jpg',
#                                                     'photo_807': 'https://sun9-17.userapi.com/c635101/v635101798/3b830/shnatl2QIhs.jpg',
#                                                     'post_id': 1137298,
#                                                     'text': 'Централизованная '
#                                                             'шина vs. Service '
#                                                             'Mesh, или Как '
#                                                             'митап превратить '
#                                                             'в баттл.\n'
#                                                             '\n'
#                                                             'Когда в '
#                                                             '«Промсвязьбанке» '
#                                                             'поняли, что '
#                                                             'проводить '
#                                                             'очередной митап '
#                                                             'им будет скучно, '
#                                                             'то решили '
#                                                             'превратить его в '
#                                                             'нечто более '
#                                                             'остросюжетное — '
#                                                             'дуэль между '
#                                                             'подходами ESB и '
#                                                             'Distributed: '
#                                                             'http://amp.gs/gcBf\n'
#                                                             '\n'
#                                                             '#разработка@habr '
#                                                             '#администрирование@habr',
#                                                     'user_id': 100,
#                                                     'width': 1138},
#                                           'type': 'photo'}],
#                          'comments': {'can_post': 1,
#                                       'count': 2,
#                                       'groups_can_post': True},
#                          'date': 1544353234,
#                          'from_id': -20629724,
#                          'id': 1137298,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 31,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -20629724,
#                          'post_source': {'type': 'api'},
#                          'post_type': 'post',
#                          'reposts': {'count': 0, 'user_reposted': 0},
#                          'text': 'Централизованная шина vs. Service Mesh, или '
#                                  'Как митап превратить в баттл.\n'
#                                  '\n'
#                                  'Когда в «Промсвязьбанке» поняли, что '
#                                  'проводить очередной митап им будет скучно, '
#                                  'то решили превратить его в нечто более '
#                                  'остросюжетное — дуэль между подходами ESB и '
#                                  'Distributed: http://amp.gs/gcBf\n'
#                                  '\n'
#                                  '#разработка@habr #администрирование@habr',
#                          'views': {'count': 26369}},
#                         {'attachments': [{'photo': {'access_key': 'faaea8f5baf17ec8e1',
#                                                     'album_id': -7,
#                                                     'date': 1544346061,
#                                                     'height': 408,
#                                                     'id': 456256381,
#                                                     'owner_id': -20629724,
#                                                     'photo_130': 'https://sun9-4.userapi.com/c635101/v635101995/2e412/sFPVsBn9gyo.jpg',
#                                                     'photo_604': 'https://sun9-3.userapi.com/c635101/v635101995/2e413/WT6Zxp9LYhM.jpg',
#                                                     'photo_75': 'https://sun9-29.userapi.com/c635101/v635101995/2e411/8FgKX4em2a4.jpg',
#                                                     'photo_807': 'https://sun9-2.userapi.com/c635101/v635101995/2e414/w3Q_tn7NtyY.jpg',
#                                                     'post_id': 1137272,
#                                                     'text': 'Российская '
#                                                             'компания вместо '
#                                                             'лечения '
#                                                             'зашифрованных '
#                                                             'файлов платит '
#                                                             'злоумышленникам.\n'
#                                                             '\n'
#                                                             'По расчётам, '
#                                                             'компания Dr. '
#                                                             'Shifro за время '
#                                                             'своей '
#                                                             'деятельности '
#                                                             'получила примерно '
#                                                             '$300 тысяч '
#                                                             'прибыли. В '
#                                                             'среднем решение '
#                                                             'одного инцидента '
#                                                             'обходилось '
#                                                             'клиентам в $3000: '
#                                                             'http://amp.gs/gc8t\n'
#                                                             '\n'
#                                                             '#разработка@habr',
#                                                     'user_id': 100,
#                                                     'width': 780},
#                                           'type': 'photo'}],
#                          'comments': {'can_post': 1,
#                                       'count': 9,
#                                       'groups_can_post': True},
#                          'date': 1544346061,
#                          'from_id': -20629724,
#                          'id': 1137272,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 62,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -20629724,
#                          'post_source': {'type': 'api'},
#                          'post_type': 'post',
#                          'reposts': {'count': 7, 'user_reposted': 0},
#                          'text': 'Российская компания вместо лечения '
#                                  'зашифрованных файлов платит '
#                                  'злоумышленникам.\n'
#                                  '\n'
#                                  'По расчётам, компания Dr. Shifro за время '
#                                  'своей деятельности получила примерно $300 '
#                                  'тысяч прибыли. В среднем решение одного '
#                                  'инцидента обходилось клиентам в $3000: '
#                                  'http://amp.gs/gc8t\n'
#                                  '\n'
#                                  '#разработка@habr',
#                          'views': {'count': 32261}},
#                         {'attachments': [{'photo': {'access_key': '4417c576b633cfd523',
#                                                     'album_id': -7,
#                                                     'date': 1544338823,
#                                                     'height': 472,
#                                                     'id': 456256380,
#                                                     'owner_id': -20629724,
#                                                     'photo_1280': 'https://sun9-18.userapi.com/c635101/v635101239/315c7/BhO88qMgOls.jpg',
#                                                     'photo_130': 'https://sun9-3.userapi.com/c635101/v635101239/315c4/ItWKh13tZSs.jpg',
#                                                     'photo_604': 'https://sun9-30.userapi.com/c635101/v635101239/315c5/-FLh7ihpoEc.jpg',
#                                                     'photo_75': 'https://sun9-3.userapi.com/c635101/v635101239/315c3/m8sA4EIxnJg.jpg',
#                                                     'photo_807': 'https://sun9-28.userapi.com/c635101/v635101239/315c6/O5HSlGfyr7g.jpg',
#                                                     'post_id': 1137258,
#                                                     'text': 'Стажёр Google, '
#                                                             'проходя обучение, '
#                                                             'случайно запустил '
#                                                             'рекламную '
#                                                             'кампанию с '
#                                                             'изменённой ценой '
#                                                             'клика, где в '
#                                                             'качестве '
#                                                             'рекламируемого '
#                                                             'объекта '
#                                                             'продвигался '
#                                                             'простой жёлтый '
#                                                             'прямоугольник.\n'
#                                                             '\n'
#                                                             'Ошибка обошлась '
#                                                             'компании в $10 '
#                                                             'миллионов: '
#                                                             'http://amp.gs/gQaS\n'
#                                                             '\n'
#                                                             '#маркетинг@habr '
#                                                             '#гиктаймс@habr',
#                                                     'user_id': 100,
#                                                     'width': 945},
#                                           'type': 'photo'}],
#                          'comments': {'can_post': 1,
#                                       'count': 18,
#                                       'groups_can_post': True},
#                          'date': 1544338823,
#                          'from_id': -20629724,
#                          'id': 1137258,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 149,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -20629724,
#                          'post_source': {'type': 'api'},
#                          'post_type': 'post',
#                          'reposts': {'count': 15, 'user_reposted': 0},
#                          'text': 'Стажёр Google, проходя обучение, случайно '
#                                  'запустил рекламную кампанию с изменённой '
#                                  'ценой клика, где в качестве рекламируемого '
#                                  'объекта продвигался простой жёлтый '
#                                  'прямоугольник.\n'
#                                  '\n'
#                                  'Ошибка обошлась компании в $10 миллионов: '
#                                  'http://amp.gs/gQaS\n'
#                                  '\n'
#                                  '#маркетинг@habr #гиктаймс@habr',
#                          'views': {'count': 36908}},
#                         {'attachments': [{'photo': {'access_key': '600d2f965bdbf16d18',
#                                                     'album_id': -7,
#                                                     'date': 1544331643,
#                                                     'height': 467,
#                                                     'id': 456256379,
#                                                     'owner_id': -20629724,
#                                                     'photo_130': 'https://sun9-3.userapi.com/c635101/v635101368/332ee/sXbBGjqvbM8.jpg',
#                                                     'photo_604': 'https://sun9-22.userapi.com/c635101/v635101368/332ef/YpSNzNIwThs.jpg',
#                                                     'photo_75': 'https://sun9-26.userapi.com/c635101/v635101368/332ed/s8CqHDNeV3k.jpg',
#                                                     'photo_807': 'https://sun9-29.userapi.com/c635101/v635101368/332f0/7sqFGx64G8Q.jpg',
#                                                     'post_id': 1137252,
#                                                     'text': 'Лазерную '
#                                                             'генерацию '
#                                                             'возможно получить '
#                                                             'в водяных парах, '
# ...
#                          'date': 1544096755,
#                          'from_id': -20629724,
#                          'id': 1136018,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 43,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -20629724,
#                          'post_source': {'type': 'api'},
#                          'post_type': 'post',
#                          'reposts': {'count': 3, 'user_reposted': 0},
#                          'text': 'Память Optane — симбиот для HDD, и '
#                                  'конфигурации офисных ПК получаются на 8-15% '
#                                  'дешевле.\n'
#                                  '\n'
#                                  'Если сравнивать SSD домашнего ПК и Optane, '
#                                  'то Optane такого же размера дороже. Но SSD '
#                                  'нужен куда большего размера — он не так '
#                                  'живуч, да к тому же может кончиться: '
#                                  'http://amp.gs/gWTU\n'
#                                  '\n'
#                                  '#администрирование@habr',
#                          'views': {'count': 26375}},
#                         {'attachments': [{'photo': {'access_key': '6c6b38b06f3ce5ccf2',
#                                                     'album_id': -7,
#                                                     'date': 1544095852,
#                                                     'height': 960,
#                                                     'id': 456256235,
#                                                     'owner_id': -20629724,
#                                                     'photo_1280': 'https://sun9-21.userapi.com/c635101/v635101149/37641/0c5uTPKt6bw.jpg',
#                                                     'photo_130': 'https://sun9-24.userapi.com/c635101/v635101149/3763e/PvA8k9GfpB4.jpg',
#                                                     'photo_604': 'https://sun9-31.userapi.com/c635101/v635101149/3763f/nD80-7y_ObE.jpg',
#                                                     'photo_75': 'https://sun9-1.userapi.com/c635101/v635101149/3763d/hgiofuhVeqY.jpg',
#                                                     'photo_807': 'https://sun9-4.userapi.com/c635101/v635101149/37640/3a02w8sa3uM.jpg',
#                                                     'post_id': 1136000,
#                                                     'text': 'Как строятся '
#                                                             'оптоволоконные '
#                                                             'сети.\n'
#                                                             '\n'
#                                                             '«Меня зовут '
#                                                             'Дмитрий, я '
#                                                             'занимаюсь '
#                                                             'проектированием и '
#                                                             'строительством '
#                                                             'волоконно-оптических '
#                                                             'линий связи в '
#                                                             'DataLine. Сегодня '
#                                                             'расскажу, как мы '
#                                                             'создаем '
#                                                             'оптические трассы '
#                                                             'для наших '
#                                                             'клиентов и как '
#                                                             'устраняем '
#                                                             'аварии»: '
#                                                             'http://amp.gs/gWjp\n'
#                                                             '\n'
#                                                             '#разработка@habr '
#                                                             '#администрирование@habr '
#                                                             '#гиктаймс@habr',
#                                                     'user_id': 100,
#                                                     'width': 1280},
#                                           'type': 'photo'}],
#                          'comments': {'can_post': 1,
#                                       'count': 50,
#                                       'groups_can_post': True},
#                          'date': 1544095853,
#                          'from_id': -20629724,
#                          'id': 1136000,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 144,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -20629724,
#                          'post_source': {'type': 'api'},
#                          'post_type': 'post',
#                          'reposts': {'count': 14, 'user_reposted': 0},
#                          'text': 'Как строятся оптоволоконные сети.\n'
#                                  '\n'
#                                  '«Меня зовут Дмитрий, я занимаюсь '
#                                  'проектированием и строительством '
#                                  'волоконно-оптических линий связи в DataLine. '
#                                  'Сегодня расскажу, как мы создаем оптические '
#                                  'трассы для наших клиентов и как устраняем '
#                                  'аварии»: http://amp.gs/gWjp\n'
#                                  '\n'
#                                  '#разработка@habr #администрирование@habr '
#                                  '#гиктаймс@habr',
#                          'views': {'count': 29011}},
#                         {'attachments': [{'doc': {'access_key': '58123db5587a6ccd04',
#                                                   'date': 1544094909,
#                                                   'ext': 'gif',
#                                                   'id': 483790612,
#                                                   'owner_id': 146891,
#                                                   'preview': {'photo': {'sizes': [{'height': 83,
#                                                                                    'src': 'https://pp.userapi.com/c848328/u15301063/d9/-3/m_cf28bf9bcd.jpg',
#                                                                                    'type': 'm',
#                                                                                    'width': 130},
#                                                                                   {'height': 64,
#                                                                                    'src': 'https://pp.userapi.com/c848328/u15301063/d9/-3/s_cf28bf9bcd.jpg',
#                                                                                    'type': 's',
#                                                                                    'width': 100},
#                                                                                   {'height': 385,
#                                                                                    'src': 'https://pp.userapi.com/c848328/u15301063/d9/-3/x_cf28bf9bcd.jpg',
#                                                                                    'type': 'x',
#                                                                                    'width': 604},
#                                                                                   {'height': 515,
#                                                                                    'src': 'https://pp.userapi.com/c848328/u15301063/d9/-3/y_cf28bf9bcd.jpg',
#                                                                                    'type': 'y',
#                                                                                    'width': 807},
#                                                                                   {'height': 816,
#                                                                                    'src': 'https://pp.userapi.com/c848328/u15301063/d9/-3/z_cf28bf9bcd.jpg',
#                                                                                    'type': 'z',
#                                                                                    'width': 1280},
#                                                                                   {'height': 815,
#                                                                                    'src': 'https://pp.userapi.com/c848328/u15301063/d9/-3/o_cf28bf9bcd.jpg',
#                                                                                    'type': 'o',
#                                                                                    'width': 1278}]},
#                                                               'video': {'file_size': 277148,
#                                                                         'height': 814,
#                                                                         'src': 'https://vk.com/doc146891_483790612?hash=cfea2660413676a909&dl=GA:1544374685:3aeda59dd163bce662&api=1&mp4=1',
#                                                                         'width': 1278}},
#                                                   'size': 768045,
#                                                   'title': 'img.gif',
#                                                   'type': 3,
#                                                   'url': 'https://vk.com/doc146891_483790612?hash=cfea2660413676a909&dl=GA:1544374685:3aeda59dd163bce662&api=1&no_preview=1'},
#                                           'type': 'doc'}],
#                          'comments': {'can_post': 1,
#                                       'count': 0,
#                                       'groups_can_post': True},
#                          'date': 1544094911,
#                          'from_id': -20629724,
#                          'id': 1135993,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 60,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -20629724,
#                          'post_source': {'type': 'api'},
#                          'post_type': 'post',
#                          'reposts': {'count': 9, 'user_reposted': 0},
#                          'text': 'Особенности внедрения гибкой разработки.\n'
#                                  '\n'
#                                  'Как понять, правильно ли внедрён Agile, '
#                                  'какая практика годится для какой задачи и '
#                                  'отрасли, кто в компании должен переводить '
#                                  'работу на «Agile-рельсы»? Своим опытом '
#                                  'делится Agile-коуч ScrumTrek Василий '
#                                  'Савунов: http://amp.gs/gLc4\n'
#                                  '\n'
#                                  '#управление@habr',
#                          'views': {'count': 24751}},
#                         {'attachments': [{'photo': {'access_key': 'f57a31e89cdd3e2356',
#                                                     'album_id': -7,
#                                                     'date': 1544094038,
#                                                     'height': 1125,
#                                                     'id': 456256234,
#                                                     'owner_id': -20629724,
#                                                     'photo_1280': 'https://sun9-1.userapi.com/c635101/v635101149/37627/gsiX75cuLQk.jpg',
#                                                     'photo_130': 'https://sun9-2.userapi.com/c635101/v635101149/37624/n-gQeDqXqpM.jpg',
#                                                     'photo_2560': 'https://sun9-34.userapi.com/c635101/v635101149/37628/Pe5EXbqOx_E.jpg',
#                                                     'photo_604': 'https://sun9-35.userapi.com/c635101/v635101149/37625/EVA-iSCHSNE.jpg',
#                                                     'photo_75': 'https://sun9-21.userapi.com/c635101/v635101149/37623/7YriU-96PYk.jpg',
#                                                     'photo_807': 'https://sun9-25.userapi.com/c635101/v635101149/37626/Q_8afKJpdKk.jpg',
#                                                     'post_id': 1135990,
#                                                     'text': 'Климат Марса: '
#                                                             'назад в будущее.\n'
#                                                             '\n'
#                                                             'Исследования '
#                                                             'циклов изменения '
#                                                             'эксцентриситета и '
#                                                             'наклона говорят о '
#                                                             'том, что '
#                                                             'глобальное '
#                                                             'потепление '
#                                                             'происходит на '
#                                                             'Красной планете '
#                                                             'прямо сейчас, '
#                                                             'хотя и с '
#                                                             'незначительной '
#                                                             'скоростью: '
#                                                             'http://amp.gs/gLMl\n'
#                                                             '\n'
#                                                             '#гиктаймс@habr',
#                                                     'user_id': 100,
#                                                     'width': 1400},
#                                           'type': 'photo'}],
#                          'comments': {'can_post': 1,
#                                       'count': 13,
#                                       'groups_can_post': True},
#                          'date': 1544094038,
#                          'from_id': -20629724,
#                          'id': 1135990,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 81,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -20629724,
#                          'post_source': {'type': 'api'},
#                          'post_type': 'post',
#                          'reposts': {'count': 3, 'user_reposted': 0},
#                          'text': 'Климат Марса: назад в будущее.\n'
#                                  '\n'
#                                  'Исследования циклов изменения '
#                                  'эксцентриситета и наклона говорят о том, что '
#                                  'глобальное потепление происходит на Красной '
#                                  'планете прямо сейчас, хотя и с '
#                                  'незначительной скоростью: '
#                                  'http://amp.gs/gLMl\n'
#                                  '\n'
#                                  '#гиктаймс@habr',
#                          'views': {'count': 28113}}]}}

# %%
pprint(data['response']['items'][0])
# Out:
# {'attachments': [{'photo': {'access_key': '9e1a8b5cb8bc3b801d',
#                             'album_id': -7,
#                             'date': 1544169649,
#                             'height': 420,
#                             'id': 456256288,
#                             'owner_id': -20629724,
#                             'photo_130': 'https://sun9-33.userapi.com/c635101/v635101837/4458f/pvOM7kijXLo.jpg',
#                             'photo_604': 'https://sun9-29.userapi.com/c635101/v635101837/44590/awP4AyVy320.jpg',
#                             'photo_75': 'https://sun9-33.userapi.com/c635101/v635101837/4458e/HBWPoRODBB0.jpg',
#                             'photo_807': 'https://sun9-34.userapi.com/c635101/v635101837/44591/28A4SqqRYfQ.jpg',
#                             'post_id': 1136473,
#                             'text': '«Не надо сразу бросаться строить '
#                                     'подводную лодку».\n'
#                                     '\n'
#                                     'Беседуем с руководителем мобильной '
#                                     'разработки «Лаборатории Касперского» '
#                                     'Виктором Яблоковым о том, чем ему помог в '
#                                     'IT математический аппарат, как мобильная '
#                                     'разработка встраивается в структуру '
#                                     'компании, с какими угрозами имеет дело '
#                                     'его команда, какие у «Лаборатории '
#                                     'Касперского» патенты и о массе других '
#                                     'технических и мировоззренческих вещей: '
#                                     'http://amp.gs/go83\n'
#                                     '\n'
#                                     '#разработка@habr #управление@habr',
#                             'user_id': 100,
#                             'width': 800},
#                   'type': 'photo'}],
#  'comments': {'can_post': 1, 'count': 1, 'groups_can_post': True},
#  'date': 1544169649,
#  'from_id': -20629724,
#  'id': 1136473,
#  'is_pinned': 1,
#  'likes': {'can_like': 1, 'can_publish': 1, 'count': 59, 'user_likes': 0},
#  'marked_as_ads': 0,
#  'owner_id': -20629724,
#  'post_source': {'type': 'api'},
#  'post_type': 'post',
#  'reposts': {'count': 9, 'user_reposted': 0},
#  'text': '«Не надо сразу бросаться строить подводную лодку».\n'
#          '\n'
#          'Беседуем с руководителем мобильной разработки «Лаборатории '
#          'Касперского» Виктором Яблоковым о том, чем ему помог в IT '
#          'математический аппарат, как мобильная разработка встраивается в '
#          'структуру компании, с какими угрозами имеет дело его команда, какие '
#          'у «Лаборатории Касперского» патенты и о массе других технических и '
#          'мировоззренческих вещей: http://amp.gs/go83\n'
#          '\n'
#          '#разработка@habr #управление@habr',
#  'views': {'count': 28763}}

# %% [markdown]
# Нужная нам статистика находится в полях 'comments', 'likes' и 'reposts'. Соберем итоговую статистику для каждого поста в словарь stats. В качестве ключа будем использовать название статьи, в качестве значения - лист с тремя интересующими нас метриками и временем публикации: [комментарии, лайки, репосты, дата публикации]. Первую строку с количеством постов не будем учитывать с помощью знакомого примера с переменной Started. API ВКонтакте возвращает два типа записей, для их корректной обработки ставим проверку "if 'attachments' in record":

# %%
def get_stats(data):
    
    Started = True

    stats = {}

    for record in data['response']['items']:

        if Started:
            Started = False   

        else:
            if 'attachments' in record:
                if 'link' in record['attachments'][0]:
                    title = record['attachments'][0]['link']['title']
                elif 'photo' in record['attachments'][0]:
                    title = record['attachments'][0]['photo']['text']

            elif 'copy_history' in record:
                if 'link' in record['copy_history'][0]['attachments'][0]:
                    title = record['copy_history'][0]['attachments'][0]['link']['title']
                elif 'poll' in record['copy_history'][0]['attachments'][0]:
                    title = record['copy_history'][0]['attachments'][0]['poll']['question']


            stats[title.split('\n')[0]] = [record['comments']['count'], record['likes']['count'], record['reposts']['count'], record['date'] ]
    
    return stats

# %%
stats = get_stats(data)
pprint(stats)
# Out:
# {'': [2, 76, 16, 1544174101],
#  '4 декабря в Лондоне прошла конференция FlutterLive, посвящённая в основном мобильному фреймворку Flutter, но не ограниченная им.': [1,
#                                                                                                                                       31,
#                                                                                                                                       3,
#                                                                                                                                       1544209260],
#  'AlphaZero снова обыграл Stockfish в матче из тысячи партий.': [4,
#                                                                  75,
#                                                                  13,
#                                                                  1544182215],
#  'Android-библиотеки и инструменты, которые не должны пройти мимо вас в 2018 году.': [2,
#                                                                                       94,
#                                                                                       11,
#                                                                                       1544184041],
#  'Apache NiFi: что это такое и краткий обзор возможностей.': [10,
#                                                               53,
#                                                               7,
#                                                               1544121024],
#  'AppsConf — самая полезная конференция по мобильной разработке, причём не только в России. Именно так получилось в октябре, и организаторы собираются это повторить уже в апреле 2019 года.': [3,
#                                                                                                                                                                                                 22,
#                                                                                                                                                                                                 3,
#                                                                                                                                                                                                 1544292065],
#  'Camunda BPM Meetup Raiffeisenbank.': [0, 8, 1, 1544193045],
#  'Conditional Access как механизм контроля доступа.': [0, 24, 1, 1544122833],
#  'Flutter 1.0.': [0, 42, 6, 1544101260],
#  'Google держит вас в персональном «поисковом пузыре», даже если вы перешли в анонимный режим.': [1,
#                                                                                                   62,
#                                                                                                   7,
#                                                                                                   1544158847],
#  'Kotlin, IT в Эстонии и туннель между Таллином и Хельсинки.': [1,
#                                                                 43,
#                                                                 2,
#                                                                 1544191241],
#  'Qualcomm представила платформу Snapdragon 855 с поддержкой 5G.': [5,
#                                                                     41,
#                                                                     2,
#                                                                     1544117476],
#  'Rust-новости за ноябрь.': [5, 24, 1, 1544097615],
#  'STM32 bootloader DFU mode с использованием CubeMX.': [3, 82, 11, 1544277644],
#  'The New iOS Mobile Enterprise. Часть первая. Кодогенерация для ресурсов.': [3,
#                                                                               58,
#                                                                               2,
#                                                                               1544130042],
#  '«10 октября 2018 года наша команда выпустила новую версию приложения React Native. Мы рады и гордимся этим. Но ужас-то какой: через несколько часов внезапно увеличивается количество сбоев под Android».': [0,
#                                                                                                                                                                                                                46,
#                                                                                                                                                                                                                7,
#                                                                                                                                                                                                                1544266862],
#  '«АльфаСмарт Дана — это самый большой «карманный компьютер» на базе Палм ОС, почти идеальная пишущая машинка на батарейках, уникальный девайс, мимо которого я просто не мог пройти».': [3,
#                                                                                                                                                                                           51,
#                                                                                                                                                                                           3,
#                                                                                                                                                                                           1544171461],
#  '«В прошлом году все кассы в стране упали почти на сутки 20 декабря, и это был день П. Но мы были частично готовы к авралу и вышли с минимальными потерями».': [5,
#                                                                                                                                                                  40,
#                                                                                                                                                                  6,
#                                                                                                                                                                  1544105761],
#  '«Друзья жалуются в дискорде на мой микрофон, слышны какие-то цифровые помехи, а если начать копировать файлы на компьютере, то вообще. Купить нормальную звуковую карту? Это не про нас».': [11,
#                                                                                                                                                                                                163,
#                                                                                                                                                                                                20,
#                                                                                                                                                                                                1544103949],
#  '«Если вы чувствуете, что идёте на поводу у своего телефона, не принимайте условия, которые вам предлагает страница настроек. Удаляйте приложения и обретайте контроль».': [7,
#                                                                                                                                                                              65,
#                                                                                                                                                                              2,
#                                                                                                                                                                              1544188540],
#  '«Если разбираешь что-то, попробуй это описать понятным языком и найти того, кто прочитает и выступит с замечаниями».': [3,
#                                                                                                                           65,
#                                                                                                                           9,
#                                                                                                                           1544175955],
#  '«Идея пришла практически сразу, потому что близится Новый Год и бот в виде «Секретного Санты» — нераспространённая вещь в Telegram, а желание написать его было ещё давно».': [1,
#                                                                                                                                                                                  36,
#                                                                                                                                                                                  1,
#                                                                                                                                                                                  1544176836],
#  '«Как мы интегрировали для магазинов SAP в Европе с кассами в России через 1С».': [0,
#                                                                                     49,
#                                                                                     8,
#                                                                                     1544106611],
#  '«Пассивная разведка — основной инструмент, который вы действительно должны попробовать».': [0,
#                                                                                               42,
#                                                                                               9,
#                                                                                               1544360422],
#  '«После того, как Иван познакомился с когортным анализом, он терпеть не мог любые виды слащавых метрик. Но ирония была в том, что руководство не знало ничего другого и знать категорически не хотело».': [3,
#                                                                                                                                                                                                             58,
#                                                                                                                                                                                                             9,
#                                                                                                                                                                                                             1544104851],
#  '«Потомок» AlphaGo самостоятельно научился играть в шахматы, сеги и го.': [9,
#                                                                             76,
#                                                                             6,
#                                                                             1544183162],
#  '«Представьте, что вы в интернет-магазине. Выбираете книгу в подарок. Сами вы её не читали, так что приходится полагаться на мнение других покупателей».': [12,
#                                                                                                                                                              53,
#                                                                                                                                                              5,
#                                                                                                                                                              1544205627],
#  '«Эй, HR, где моя сувенирка?»': [8, 65, 4, 1544284817],
#  '«Я решил посмотреть, что происходит, и задокументировать места, которые можно улучшить. В результате этого бенчмарка и изучения этой проблемы мы обнаружили три области, в которых возможно улучшение».': [0,
#                                                                                                                                                                                                              35,
#                                                                                                                                                                                                              2,
#                                                                                                                                                                                                              1544099442],
#  'Австралийская компания Ferox Advanced Vehicles представила концепт внедорожника со встроенными в колёса жидкостными моторами.': [31,
#                                                                                                                                    178,
#                                                                                                                                    15,
#                                                                                                                                    1544118333],
#  'Бегущий в лабиринте: анализ нейронной активности мозга крысы в реальном времени.': [3,
#                                                                                       67,
#                                                                                       8,
#                                                                                       1544274036],
#  'Белые кресла, солидные лица…': [21, 52, 6, 1544194853],
#  'Благодаря зрению мы получаем 90% информации об окружающем мире. Это, в принципе, самый важный из наших «датчиков окружающего мира». И к нему просто необходимо относится внимательно.': [4,
#                                                                                                                                                                                            93,
#                                                                                                                                                                                            10,
#                                                                                                                                                                                            1544248808],
#  'В 2018 году в Питерской Вышке открылась Санкт-Петербургская школа физико-математических и компьютерных наук.': [2,
#                                                                                                                   30,
#                                                                                                                   2,
#                                                                                                                   1544098522],
#  'В исходном коде файлов PlayStation Classic найдены десятки названий игр не из основного списка и скрытое меню.': [24,
#                                                                                                                     81,
#                                                                                                                     5,
#                                                                                                                     1544124654],
#  'В начале этой недели состоялся очередной релиз Kubernetes, который окрестили «ангельским», — 1.13.': [1,
#                                                                                                         17,
#                                                                                                         2,
#                                                                                                         1544181330],
#  'В середине октября в рамках проходящего в Томске молодёжного форума U-NOVUS был проведён воркшоп, посвящённый Data Science. В качестве кейса была дана задача по продвинутой аналитике на нефтехимическом предприятии.': [0,
#                                                                                                                                                                                                                             13,
#                                                                                                                                                                                                                             0,
#                                                                                                                                                                                                                             1544164260],
#  'Власти Китая собирают информацию с электромобилей граждан страны.': [17,
#                                                                        51,
#                                                                        9,
#                                                                        1544103023],
#  'Вырываемся в top10, или Бот для игры в Telegram.': [1, 30, 3, 1544173250],
#  'Высокодоступный и масштабируемый Elasticsearch в Kubernetes.': [0,
#                                                                   73,
#                                                                   17,
#                                                                   1544299257],
#  'Говорят, что фриланс выбирают для того, чтобы не нужно было ходить в офис. А вот разработчик Вячеслав Балобанов считает, что офис для работы — лучше любого пляжа. ': [3,
#                                                                                                                                                                          65,
#                                                                                                                                                                          6,
#                                                                                                                                                                          1544115588],
#  'Даша хочет стать проектировщицей процессоров. Почему бы ей не сделать нейроускоритель на ПЛИС?': [15,
#                                                                                                     114,
#                                                                                                     8,
#                                                                                                     1544198422],
#  'Дружба, благодаря которой Google вырос до огромных размеров.': [4,
#                                                                   122,
#                                                                   9,
#                                                                   1544167811],
#  'Забираем почту без SMS и регистрации.': [0, 69, 6, 1544108474],
#  'Зависимые типы — будущее языков программирования.': [159,
#                                                        407,
#                                                        73,
#                                                        1544286791],
#  'Игра CS:GO стала бесплатной.': [69, 105, 7, 1544263223],
#  'Как обрабатывать ошибки на JVM быстрее.': [6, 49, 4, 1544201975],
#  'Как организовать работу «удалёнщиков».': [13, 106, 9, 1544256027],
#  'Как помочь ERP-системе справиться с полумиллионом запросов в секунду.': [2,
#                                                                            104,
#                                                                            18,
#                                                                            1544295630],
#  'Как превратить клиента в данные: меняем видеонаблюдение и видеоаналитику для ритейла.': [11,
#                                                                                            53,
#                                                                                            6,
#                                                                                            1544190318],
#  'Как строятся оптоволоконные сети.': [0, 60, 9, 1544094911],
#  'Класс PHP для вывода в консоль цветного текста.': [8, 60, 8, 1544175052],
#  'Климат Марса: назад в будущее.': [13, 81, 3, 1544094038],
#  'Краткий гид по обучению С++: что, когда и на чём создавать.': [29,
#                                                                  414,
#                                                                  39,
#                                                                  1544203846],
#  'Курс MIT «Computer Systems Security» посвящён разработке и внедрению защищённых компьютерных систем. Лекции охватывают модели угроз, атаки, которые ставят под угрозу безопасность, и методы обеспечения безопасности на основе последних научных работ. Темы включают в себя безопасность операционной системы, возможности, управление потоками информации, языковую безопасность, сетевые протоколы, аппаратную защиту и безопасность в веб-приложениях.': [24,
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                  169,
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                  21,
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                  1544111100],
#  'Лазерную генерацию возможно получить в водяных парах, в красителях, добытых из фломастеров, в конце концов, в углекислом газе. Но есть ещё одна рабочая среда лазера, которая распространена гораздо больше, чем все остальные вместе взятые. Это азот, которого 78% в атмосферном воздухе.': [4,
#                                                                                                                                                                                                                                                                                                  135,
#                                                                                                                                                                                                                                                                                                  19,
#                                                                                                                                                                                                                                                                                                  1544331643],
#  'На прошедшей неделе мы разочаровывались в диджитал-услугах, тестировали новый 2ГИС, знакомились с «Яндекс.Телефоном», ваяли 2D-квест по Лавкрафту и радовались переходу на опенсорс самого популярного в мире движка физической симуляции.': [15,
#                                                                                                                                                                                                                                                 52,
#                                                                                                                                                                                                                                                 5,
#                                                                                                                                                                                                                                                 1544356897],
#  'Несколько дней назад появились слухи, что Microsoft разрабатывает браузер на базе Chromium, который будет поставляться по умолчанию вместо Edge.': [36,
#                                                                                                                                                       43,
#                                                                                                                                                       3,
#                                                                                                                                                       1544185859],
#  'Несколько дней назад стартап Waymo, принадлежащий Alphabet, запустил в коммерческую эксплуатацию беспилотное такси.': [1,
#                                                                                                                          32,
#                                                                                                                          3,
#                                                                                                                          1544367635],
#  'Новости из мира OpenStreetMap №436 (20-26 ноября): http://amp.gs/gooM': [1,
#                                                                            16,
#                                                                            4,
#                                                                            1544186753],
#  'О композиции функций в JavaScript.': [1, 61, 11, 1544102124],
#  'Обзор нововведений Android Design Support Library v28.': [0,
#                                                             45,
#                                                             7,
#                                                             1544211025],
#  'Олдскульные игры и немного грибов: mission completed.': [6,
#                                                            26,
#                                                            4,
#                                                            1544212864],
#  'Память Optane — симбиот для HDD, и конфигурации офисных ПК получаются на 8-15% дешевле.': [12,
#                                                                                              43,
#                                                                                              3,
#                                                                                              1544096755],
#  'Подключайтесь к публичному тестированию нового 2ГИС!': [36,
#                                                           157,
#                                                           4,
#                                                           1544155215],
#  'Половина компьютеров промышленных предприятий России в 2018 году подвергалась хакерским атакам.': [5,
#                                                                                                      53,
#                                                                                                      15,
#                                                                                                      1544207441],
#  'Последняя версия Angular, благодаря усилиям команды разработчиков и сообщества энтузиастов, хорошо оптимизирована. Однако когда речь заходит о конкретном приложении, нельзя забывать о некоторых вещах, которые влияют на его производительность.': [1,
#                                                                                                                                                                                                                                                         60,
#                                                                                                                                                                                                                                                         9,
#                                                                                                                                                                                                                                                         1544113822],
#  'Почему у React-элементов есть свойство $$typeof?': [0, 82, 14, 1544200231],
#  'Разнообразие браузеров начинается с нас.': [65, 129, 17, 1544270441],
#  'Роботакси Waymo One заработало в качестве коммерческой транспортной сети.': [8,
#                                                                                27,
#                                                                                5,
#                                                                                1544189442],
#  'Роботы начинают справляться с манипулированием произвольными объектами.': [0,
#                                                                              89,
#                                                                              14,
#                                                                              1544126428],
#  'Роскомнадзор предложил ввести новую возрастную категорию для маркировки контента — 1+ и 3+.': [23,
#                                                                                                  38,
#                                                                                                  9,
#                                                                                                  1544110234],
#  'Российская компания вместо лечения зашифрованных файлов платит злоумышленникам.': [9,
#                                                                                      62,
#                                                                                      7,
#                                                                                      1544346061],
#  'С точки зрения отечественного градостроительного и противопожарного законодательства, в России нет зданий выше 50 метров. Как же быть тем, кто решил посетить самый высокий российский небоскрёб? Это безопасно?': [4,
#                                                                                                                                                                                                                       50,
#                                                                                                                                                                                                                       4,
#                                                                                                                                                                                                                       1544184914],
#  'Светодиодные лампы из Украины.': [35, 52, 5, 1544162437],
#  'Сегодня «Яндекс.Облако» стало доступно всем. Теперь любой пользователь может зайти туда и развернуть необходимые ему ресурсы, получив доступ к технологиям «Яндекса». Например, к распознаванию речи.': [16,
#                                                                                                                                                                                                            177,
#                                                                                                                                                                                                            25,
#                                                                                                                                                                                                            1544179564],
#  'Сегодня стартует миссия «Чанъэ-4».': [5, 65, 9, 1544187647],
#  'Семь лет образовательным проектам Mail. Ru Group.': [2, 37, 2, 1544100337],
#  'Сервис по управлению собственной жизнью.': [5, 178, 25, 1544180438],
#  'Согласно новому исследованию, примерно 22% пользователей Tumlr просматривают на сайте преимущественно порнографический контент.': [23,
#                                                                                                                                      100,
#                                                                                                                                      13,
#                                                                                                                                      1544214642],
#  'Стажёр Google, проходя обучение, случайно запустил рекламную кампанию с изменённой ценой клика, где в качестве рекламируемого объекта продвигался простой жёлтый прямоугольник.': [18,
#                                                                                                                                                                                      149,
#                                                                                                                                                                                      15,
#                                                                                                                                                                                      1544338823],
#  'Старые секреты быстрой отладки: анимация исходного кода.': [8,
#                                                               83,
#                                                               12,
#                                                               1544259624],
#  'Требуется «Html-верстальщик»': [6, 7, 0, 1544187000],
#  'Требуется «QA Engineer / Ручное и автоматическое тестирование»': [1,
#                                                                     9,
#                                                                     0,
#                                                                     1544100540],
#  'Требуется «React Native developer»': [3, 6, 0, 1544359800],
#  'Требуется «Интернет маркетолог / Performance Marketing»': [1,
#                                                              6,
#                                                              0,
#                                                              1544273400],
#  'У Parallels — тринадцать офисов по всему миру. И если разработка сконцентрирована в основном в России, Эстонии и на Мальте, продажи в Северной Америке и Европе, то техническая поддержка распределена сразу между несколькими странами.': [0,
#                                                                                                                                                                                                                                               27,
#                                                                                                                                                                                                                                               2,
#                                                                                                                                                                                                                                               1544281354],
#  'Универсальный многорежимный 5G-модем.': [0, 29, 2, 1544166047],
#  'Функциональное мышление. Часть пятая.': [1, 100, 8, 1544119222],
#  'Централизованная шина vs. Service Mesh, или Как митап превратить в баттл.': [2,
#                                                                                31,
#                                                                                0,
#                                                                                1544353234],
#  'Что нового в AppCode 2018.3.': [0, 19, 0, 1544128254],
#  'Язык визуального программирования — это такой язык, который позволяет программисту создавать программы, манипулируя графическими элементами, а не печатая текстовые команды.': [2,
#                                                                                                                                                                                   150,
#                                                                                                                                                                                   17,
#                                                                                                                                                                                   1544177763],
#  '✔️ ЦБ просит малые банки искать запасного партнёра по обслуживанию карт;': [8,
#                                                                               36,
#                                                                               5,
#                                                                               1544252421]}

# %%
for title, line in sorted(stats.items(), key=lambda x: -x[1][0])[:10]:

    print(title, line)
# Out:
# Зависимые типы — будущее языков программирования. [159, 407, 73, 1544286791]
# Игра CS:GO стала бесплатной. [69, 105, 7, 1544263223]
# Разнообразие браузеров начинается с нас. [65, 129, 17, 1544270441]
# Несколько дней назад появились слухи, что Microsoft разрабатывает браузер на базе Chromium, который будет поставляться по умолчанию вместо Edge. [36, 43, 3, 1544185859]
# Подключайтесь к публичному тестированию нового 2ГИС! [36, 157, 4, 1544155215]
# Светодиодные лампы из Украины. [35, 52, 5, 1544162437]
# Австралийская компания Ferox Advanced Vehicles представила концепт внедорожника со встроенными в колёса жидкостными моторами. [31, 178, 15, 1544118333]
# Краткий гид по обучению С++: что, когда и на чём создавать. [29, 414, 39, 1544203846]
# В исходном коде файлов PlayStation Classic найдены десятки названий игр не из основного списка и скрытое меню. [24, 81, 5, 1544124654]
# Курс MIT «Computer Systems Security» посвящён разработке и внедрению защищённых компьютерных систем. Лекции охватывают модели угроз, атаки, которые ставят под угрозу безопасность, и методы обеспечения безопасности на основе последних научных работ. Темы включают в себя безопасность операционной системы, возможности, управление потоками информации, языковую безопасность, сетевые протоколы, аппаратную защиту и безопасность в веб-приложениях. [24, 169, 21, 1544111100]

# %% [markdown]
# # Время публикации постов
# На прошлом шаге мы получили список постов с комментариями, лайками, репостами и датой публикации в UNIX-формате. Осталось отфильтровать результаты по дате, чтобы оставить посты только за вчерашний день. Переведем время публикации постов из UNIX-формата в дату:

# %%
from datetime import datetime, timedelta

for title, line in stats.items():

    line.append(datetime.fromtimestamp(line[3]).strftime('%Y-%m-%d'))

    print(line)
# Out:
# [1, 32, 3, 1544367635, '2018-12-09']
# [0, 42, 9, 1544360422, '2018-12-09']
# [3, 6, 0, 1544359800, '2018-12-09']
# [15, 52, 5, 1544356897, '2018-12-09']
# [2, 31, 0, 1544353234, '2018-12-09']
# [9, 62, 7, 1544346061, '2018-12-09']
# [18, 149, 15, 1544338823, '2018-12-09']
# [4, 135, 19, 1544331643, '2018-12-09']
# [0, 73, 17, 1544299257, '2018-12-08']
# [2, 104, 18, 1544295630, '2018-12-08']
# [3, 22, 3, 1544292065, '2018-12-08']
# [159, 407, 73, 1544286791, '2018-12-08']
# [8, 65, 4, 1544284817, '2018-12-08']
# [0, 27, 2, 1544281354, '2018-12-08']
# [3, 82, 11, 1544277644, '2018-12-08']
# [3, 67, 8, 1544274036, '2018-12-08']
# [1, 6, 0, 1544273400, '2018-12-08']
# [65, 129, 17, 1544270441, '2018-12-08']
# [0, 46, 7, 1544266862, '2018-12-08']
# [69, 105, 7, 1544263223, '2018-12-08']
# [8, 83, 12, 1544259624, '2018-12-08']
# [13, 106, 9, 1544256027, '2018-12-08']
# [8, 36, 5, 1544252421, '2018-12-08']
# [4, 93, 10, 1544248808, '2018-12-08']
# [23, 100, 13, 1544214642, '2018-12-07']
# [6, 26, 4, 1544212864, '2018-12-07']
# [0, 45, 7, 1544211025, '2018-12-07']
# [1, 31, 3, 1544209260, '2018-12-07']
# [5, 53, 15, 1544207441, '2018-12-07']
# [12, 53, 5, 1544205627, '2018-12-07']
# [29, 414, 39, 1544203846, '2018-12-07']
# [6, 49, 4, 1544201975, '2018-12-07']
# [0, 82, 14, 1544200231, '2018-12-07']
# [15, 114, 8, 1544198422, '2018-12-07']
# [21, 52, 6, 1544194853, '2018-12-07']
# [0, 8, 1, 1544193045, '2018-12-07']
# [1, 43, 2, 1544191241, '2018-12-07']
# [11, 53, 6, 1544190318, '2018-12-07']
# [8, 27, 5, 1544189442, '2018-12-07']
# [7, 65, 2, 1544188540, '2018-12-07']
# [5, 65, 9, 1544187647, '2018-12-07']
# [6, 7, 0, 1544187000, '2018-12-07']
# [1, 16, 4, 1544186753, '2018-12-07']
# [36, 43, 3, 1544185859, '2018-12-07']
# [4, 50, 4, 1544184914, '2018-12-07']
# [2, 94, 11, 1544184041, '2018-12-07']
# [9, 76, 6, 1544183162, '2018-12-07']
# [4, 75, 13, 1544182215, '2018-12-07']
# [1, 17, 2, 1544181330, '2018-12-07']
# [5, 178, 25, 1544180438, '2018-12-07']
# [16, 177, 25, 1544179564, '2018-12-07']
# [2, 150, 17, 1544177763, '2018-12-07']
# [1, 36, 1, 1544176836, '2018-12-07']
# [3, 65, 9, 1544175955, '2018-12-07']
# [8, 60, 8, 1544175052, '2018-12-07']
# [2, 76, 16, 1544174101, '2018-12-07']
# [1, 30, 3, 1544173250, '2018-12-07']
# [3, 51, 3, 1544171461, '2018-12-07']
# [4, 122, 9, 1544167811, '2018-12-07']
# [0, 29, 2, 1544166047, '2018-12-07']
# [0, 13, 0, 1544164260, '2018-12-07']
# [35, 52, 5, 1544162437, '2018-12-07']
# [1, 62, 7, 1544158847, '2018-12-07']
# [36, 157, 4, 1544155215, '2018-12-07']
# [3, 58, 2, 1544130042, '2018-12-07']
# [0, 19, 0, 1544128254, '2018-12-06']
# [0, 89, 14, 1544126428, '2018-12-06']
# [24, 81, 5, 1544124654, '2018-12-06']
# [0, 24, 1, 1544122833, '2018-12-06']
# [10, 53, 7, 1544121024, '2018-12-06']
# [1, 100, 8, 1544119222, '2018-12-06']
# [31, 178, 15, 1544118333, '2018-12-06']
# [5, 41, 2, 1544117476, '2018-12-06']
# [3, 65, 6, 1544115588, '2018-12-06']
# [1, 60, 9, 1544113822, '2018-12-06']
# [24, 169, 21, 1544111100, '2018-12-06']
# [23, 38, 9, 1544110234, '2018-12-06']
# [0, 69, 6, 1544108474, '2018-12-06']
# [0, 49, 8, 1544106611, '2018-12-06']
# [5, 40, 6, 1544105761, '2018-12-06']
# [3, 58, 9, 1544104851, '2018-12-06']
# [11, 163, 20, 1544103949, '2018-12-06']
# [17, 51, 9, 1544103023, '2018-12-06']
# [1, 61, 11, 1544102124, '2018-12-06']
# [0, 42, 6, 1544101260, '2018-12-06']
# [1, 9, 0, 1544100540, '2018-12-06']
# [2, 37, 2, 1544100337, '2018-12-06']
# [0, 35, 2, 1544099442, '2018-12-06']
# [2, 30, 2, 1544098522, '2018-12-06']
# [5, 24, 1, 1544097615, '2018-12-06']
# [12, 43, 3, 1544096755, '2018-12-06']
# [0, 60, 9, 1544094911, '2018-12-06']
# [13, 81, 3, 1544094038, '2018-12-06']

# %% [markdown]
# Получаем вчерашнюю дату:

# %%
yesterday = (datetime.now() - timedelta(days = 1)).strftime('%Y-%m-%d')

print(yesterday)
# Out:
# 2018-12-08

# %% [markdown]
# Выводим обновленный рейтинг лучших постов с фильтром на вчерашнюю дату:

# %%
for title, line in sorted(stats.items(), key = lambda x: -(sum(x[1][:3]))):

    if line[4] == yesterday:

        print(title, line)
# Out:
# Зависимые типы — будущее языков программирования. [159, 407, 73, 1544286791, '2018-12-08']
# Разнообразие браузеров начинается с нас. [65, 129, 17, 1544270441, '2018-12-08']
# Игра CS:GO стала бесплатной. [69, 105, 7, 1544263223, '2018-12-08']
# Как организовать работу «удалёнщиков». [13, 106, 9, 1544256027, '2018-12-08']
# Как помочь ERP-системе справиться с полумиллионом запросов в секунду. [2, 104, 18, 1544295630, '2018-12-08']
# Благодаря зрению мы получаем 90% информации об окружающем мире. Это, в принципе, самый важный из наших «датчиков окружающего мира». И к нему просто необходимо относится внимательно. [4, 93, 10, 1544248808, '2018-12-08']
# Старые секреты быстрой отладки: анимация исходного кода. [8, 83, 12, 1544259624, '2018-12-08']
# STM32 bootloader DFU mode с использованием CubeMX. [3, 82, 11, 1544277644, '2018-12-08']
# Высокодоступный и масштабируемый Elasticsearch в Kubernetes. [0, 73, 17, 1544299257, '2018-12-08']
# Бегущий в лабиринте: анализ нейронной активности мозга крысы в реальном времени. [3, 67, 8, 1544274036, '2018-12-08']
# «Эй, HR, где моя сувенирка?» [8, 65, 4, 1544284817, '2018-12-08']
# «10 октября 2018 года наша команда выпустила новую версию приложения React Native. Мы рады и гордимся этим. Но ужас-то какой: через несколько часов внезапно увеличивается количество сбоев под Android». [0, 46, 7, 1544266862, '2018-12-08']
# ✔️ ЦБ просит малые банки искать запасного партнёра по обслуживанию карт; [8, 36, 5, 1544252421, '2018-12-08']
# У Parallels — тринадцать офисов по всему миру. И если разработка сконцентрирована в основном в России, Эстонии и на Мальте, продажи в Северной Америке и Европе, то техническая поддержка распределена сразу между несколькими странами. [0, 27, 2, 1544281354, '2018-12-08']
# AppsConf — самая полезная конференция по мобильной разработке, причём не только в России. Именно так получилось в октябре, и организаторы собираются это повторить уже в апреле 2019 года. [3, 22, 3, 1544292065, '2018-12-08']
# Требуется «Интернет маркетолог / Performance Marketing» [1, 6, 0, 1544273400, '2018-12-08']

# %% [markdown]
# # Домашнее задание
# (1 возможный балл)
# Для подсчета эффективности работы SMM-команды используют метрику индекс вовлеченности. Индекс рассчитывается как отношение количества подписчиков группы к сумме комментариев, лайков и репостов всех записей за определенный период. Чем этот показатель меньше, тем более активно подписчики группы реагируют на публикуемый в ней контент.
#
# Сравните по этому показалю две группы: https://vk.com/habr и https://vk.com/popularmechanics
#
# Для вычислений используйте следующий упрощенный алгоритм:
#
# 1. Выгрузите 100 последних постов из каждой группы
#
# 2. Посчитайте сумму комментариев, лайков и репостов этих публикаций для каждой группы
#
# 3. Получите количество подписчиков каждой группы (это число возвращает метод groups.getMembers)
#
# 4. Вычислите индекс вовлеченности для каждой группы
#
# При выполнении этого упражнения были получены следующие значения индекса: 95.46 у Хабра и 70.08 у Популярной Механики. У какой группы показатель индекса вовлеченности лучше?

# %%
def get_members(group_id):
    
    url = 'https://api.vk.com/method/groups.getMembers'

    params = {
        'group_id': group_id,
        'v': 5.73,
        'access_token': token
    }

    r = requests.get(url, params=params)

    return r.json()

# %%
get_members('habr')['response']['count']
# Out:
# 785676

# %%
habr_articles = get_100articles('habr')
habr_nmembers = get_members('habr')['response']['count']
habr_stats = get_stats(habr_articles)

popmech_articles = get_100articles('popularmechanics')
popmech_nmembers = get_members('popularmechanics')['response']['count']
popmech_stats = get_stats(popmech_articles)

# %%
habr_ei = habr_nmembers / sum([sum(i) for i in zip(*habr_stats.values())][:3])
popmech_ei = popmech_nmembers / sum([sum(i) for i in zip(*popmech_stats.values())][:3])

# %% [markdown]
# Правильность посчитанных цифр под вопросом, тк нет корректной проверки ДЗ.

# %%
habr_ei, popmech_ei
# Out:
# (94.39805358644719, 107.50499782703173)
