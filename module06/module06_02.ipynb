# %%
import pandas as pd
import numpy as np

# %%
ratings = pd.read_csv('./module05_files/ratings.csv')
movies = pd.read_csv('./module06_files/movies.csv')

# %%
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %% [markdown]
# # Упражнение
# (1 возможный балл)
# Посчитайте какое количество фильмов в датафрейме movies относится к жанру Fantasy? Т. е. найдите количество строк, у которых в столбце genres упоминается слово 'Fantasy'. Напомним, что для такого фильтра можно использовать метод str.contains

# %%
movies[movies['genres'].str.contains('Fantasy')].count()
# Out:
# movieId    654
# title      654
# genres     654
# dtype: int64

# %%
joined = ratings.merge(movies, on='movieId', how='left')

# %%
joined
# Out:
#         userId  movieId  rating   timestamp  \
# 0            1       31     2.5  1260759144
# 1            1     1029     3.0  1260759179
# 2            1     1061     3.0  1260759182
# 3            1     1129     2.0  1260759185
# 4            1     1172     4.0  1260759205
# 5            1     1263     2.0  1260759151
# 6            1     1287     2.0  1260759187
# 7            1     1293     2.0  1260759148
# 8            1     1339     3.5  1260759125
# 9            1     1343     2.0  1260759131
# 10           1     1371     2.5  1260759135
# 11           1     1405     1.0  1260759203
# 12           1     1953     4.0  1260759191
# 13           1     2105     4.0  1260759139
# 14           1     2150     3.0  1260759194
# 15           1     2193     2.0  1260759198
# 16           1     2294     2.0  1260759108
# 17           1     2455     2.5  1260759113
# 18           1     2968     1.0  1260759200
# 19           1     3671     3.0  1260759117
# ...

# %%
len(ratings) == len(joined)
# Out:
# True

# %% [markdown]
# # УПРАЖНЕНИЕ
# Вам даны выгрузки статистики рекламных кампаний из Яндекс.Директа (файл direct_stats.tsv) и заказов на сайте из CRM (файл crm_stats.tsv). В файле со статистикой Яндекс.Директа приведены данные по открученной рекламе: для каждой кампании (столбец campaign) есть показы объявлений, клики и расходы. В файле с  выгрузкой CRM - для этих же кампаний сумма заказов на сайте (столбец orders).
#
# 1Вам необходимо совместить эти выгрузки по дате и названию кампании. И посчитать стоимость заказа для каждой кампании за каждый день. Т. е. отношение расходов (столбец cost) к количеству заказов (столбец orders).

# %% [markdown]
# # Онлайн-проверка
# (1 возможный балл)
# Какое значение стоимости заказа получится к кампании landings_promo за 1 января 2018? Ответ округлите до ближайшего целого числа. Пример ответа: 698

# %%
direct_stats = pd.read_csv('./module06_files/direct_stats.tsv', sep='\t')
crm_stats = pd.read_csv('./module06_files/crm_stats.tsv', sep='\t')

# %%
direct_stats.head()
# Out:
#          date                 campaign     views  clicks     cost
# 0  2018-01-01           landings_promo  38120423   49557  1139801
# 1  2018-01-01       homepage_partner_1   5729483   12605   189073
# 2  2018-01-01       homepage_partner_2   4412029    9265   176040
# 3  2018-01-01  socdem_w_25-34_vip_test    913823    2559    89555
# 4  2018-01-02           landings_promo  40873806   61311  1471457

# %%
crm_stats.head()
# Out:
#          date                 campaign  orders
# 0  2018-01-01           landings_promo    1487
# 1  2018-01-01       homepage_partner_1     386
# 2  2018-01-01       homepage_partner_2     315
# 3  2018-01-01  socdem_w_25-34_vip_test      85
# 4  2018-01-02           landings_promo    1605

# %%
stats_j = direct_stats.merge(crm_stats, on=['date', 'campaign'], how='left')
stats_j['cost_per_order'] = stats_j['cost'] / stats_j['orders']
stats_filter = (stats_j['campaign'] == 'landings_promo') & (stats_j['date'] == '2018-01-01')
print('Answer: {:.0f}'.format(stats_j[stats_filter]['cost_per_order'][0]))
# Out:
# Answer: 767

# %% [markdown]
# # СЧИТАЕМ РЕЙТИНГИ ЖАНРОВ
#
#
# Итак, теперь для каждой строки датафрейма joined нам нужно выделить рейтинги жанров из списка genres. Напомним список жанров, которые нам интересны:

# %%
genres = ['Drama', 'Action', 'Thriller']

# %% [markdown]
# Т. е. для каждой строки joined нам нужно добавить 3 столбца для жанров Drama, Action и Thriller.
#
# Если жанр встречается в текущей строке, то присвоить ему значение столбца rating. Если жанра в строке нет, то ставим пустое значение np.NaN (т. е. указываем, что в ячейке нет числа).
#
# Здесь нам пригодится библиотека numpy (которую мы обозначили как np). А пустое значение ставим, чтобы при подсчете среднего эти строки не учитывались в результате. Можно было ставить 0, но тогда это сильно исказит итоговый средний рейтинг жанра.
#
# Напишем отдельную функцию для этой операции, а потом применим ее к каждой строке датафрейма joined с помощью метода apply. Соответственно, логика функции должна быть такой:
#
# 1. Функция должна возвращать столько же столбцов, сколько элементов в списке genres.
#
# 2. Вместо названий жанров надо подставлять значение столбца rating, если жанр есть в столбце genres датафрейма.
#
# 3. Если названия жанра не оказалось, то возвращаем np.NaN
#
# С помощью list comprehension эти требования можно уместить в одну строку:

# %%
def genres_ratings(row):

    return pd.Series([row['rating'] 
                      if genre in row['genres'] 
                      else np.NaN for genre in genres])

# %%
joined[genres] = joined.apply(genres_ratings, axis=1)

# %%
joined.head()
# Out:
#    userId  movieId  rating   timestamp  \
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205
#
#                                             title  \
# 0                          Dangerous Minds (1995)
# 1                                    Dumbo (1941)
# 2                                 Sleepers (1996)
# 3                     Escape from New York (1981)
# 4  Cinema Paradiso (Nuovo cinema Paradiso) (1989)
#
#                              genres  Drama  Action  Thriller
# 0                             Drama    2.5     NaN       NaN
# 1  Animation|Children|Drama|Musical    3.0     NaN       NaN
# 2                          Thriller    NaN     NaN       3.0
# 3  Action|Adventure|Sci-Fi|Thriller    NaN     2.0       2.0
# 4                             Drama    4.0     NaN       NaN

# %% [markdown]
# Выводим итоговый результат:

# %%
for genre in genres:
    print('{} mean rating {:.2f}'.format(genre, joined[genre].mean()))
# Out:
# Drama mean rating 3.68
# Action mean rating 3.45
# Thriller mean rating 3.52

# %% [markdown]
# # ПРОВЕРОЧНОЕ ЗАДАНИЕ
#
#
# Вам необходимо установить какие жанры фильмов имеют меньше всего оценок в наших данных. В качестве списка жанров используйте расширенную версию:

# %%
ext_genres = ['Drama', 'Action', 'Thriller', 'Comedy', 'Romance', 'War', 'Mystery', 'Crime']

# %% [markdown]
# # Онлайн-проверка
# (1 возможный балл)
# Какое количество оценок имеет жанр с наименьшим количеством рейтингов?

# %%
joined[ext_genres] = joined.apply(genres_ratings, axis=1)

# %%
joined[joined[ext_genres].count().idxmin()].count()
# Out:
# 5025
